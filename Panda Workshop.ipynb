# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
pr.read_wps(r"C:\Users\My dell\Downloads\data.xlsx"\data.wps")
# Out:
#   Cell In[6], line 1
#     pr.read_wps(r"C:\Users\My dell\Downloads\data.xlsx"\data.wps")
#                                                         ^
# SyntaxError: unexpected character after line continuation character

# %%
df.shape

# %%
len(df)

# %%
df.isnull()

# %%
df.isna()

# %%
df.isnull().sum()

# %%
df.isna().sum()

# %%
id(df)

# %%
df.columns

# %%
len(def.columns)

# %%
df.info()

# %%
type(df)

# %%
df.head()

# %%
df.tail()

# %%
df.head(3)

# %%
df.columns

# %%
df["country name"]

# %%
df[["country name , Birt rate"]}

# %%
df.columns

# %%
df_num = df[[["country name","Country code","Incomegroup]]]
df_nums

# %%
df_cat = df[[["country name","Country code","Incomegroup"]]]
df_cat

# %%
print(df.shape)
print(df_num.shape)
print(df_)
