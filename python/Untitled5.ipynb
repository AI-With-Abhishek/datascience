# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
import datetime
dti = pd.to_datetime(
    ["1/1/2018", np.datetime("2018-01-01"), datetime.datetime(2018, 1, 1)]
)
dti
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 import datetime
#       2 dti = pd.to_datetime(
# ----> 3     ["1/1/2018", np.datetime("2018-01-01"), datetime.datetime(2018, 1, 1)]
#       4 )
#       5 dti
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'datetime'
