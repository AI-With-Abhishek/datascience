# %%
1+1
# Out:
# 2

# %%
2-1
# Out:
# 1

# %%
3*4
# Out:
# 12

# %%
8/4
# Out:
# 2.0

# %%
8//4
# Out:
# 2

# %%
8+9-7
# Out:
# 10

# %%
5+5*5
# Out:
# 30

# %%
(5+5)*5
# Out:
# 50

# %%
2*2*2*2*2
# Out:
# 32

# %%
2*5
# Out:
# 10

# %%
2**5
# Out:
# 32

# %%
3**9
# Out:
# 19683

# %%
15/3
# Out:
# 5.0

# %%
10//3
# Out:
# 3

# %%
15%2
# Out:
# 1

# %%
10%2
# Out:
# 0

# %%
-10//3
# Out:
# -4

# %%
3+"int"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 3+"int"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
3+"rainy"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 3+"rainy"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
3*"nit"
# Out:
# 'nitnitnit'

# %%
a,b,c,d,e = 15, 7.8, "nit", 8+9j,True
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 15
# 7.8
# nit
# (8+9j)
# True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>

# %%
type(c)
# Out:
# str

# %%
"Google"
# Out:
# 'Google'

# %%
print("Max it")
# Out:
# Max it

# %%
max it "technology"
# Out:
#   Cell In[32], line 1
#     max it "technology"
#         ^
# SyntaxError: invalid syntax

# %%
s1 = "max it technology"

# %%
s1
# Out:
# 'max it technology'

# %%
a = 2
b = 3
a+b
# Out:
# 5

# %%
c = a +b

# %%
a = 3
b = "hi"
c = a + b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 a = 3
#       2 b = "hi"
# ----> 3 c = a + b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print("max it's"technology"')
# Out:
#   Cell In[40], line 1
#     print("max it's"technology"')
#                               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("max it's"technology"'")
# Out:
#   Cell In[41], line 1
#     print("max it's"technology"'")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
max it's"technology"')

# %%
import streamlit as st
st.write("Hello,world!")
# Out:
# 2026-02-06 10:13:31.400 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 10:13:31.800
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\My dell\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-06 10:13:31.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-06 10:13:31.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
