# %%
age = 20
if age >= 18:
    print("Eligible to vote.")
# Out:
# Eligible to vote.

# %%
age = 20
if age >= 15:
    print("Eligible to vote.")
# Out:
# Eligible to vote.

# %%
age = 19
if age > 18: print("Eligible to vote.")
# Out:
# Eligible to vote.

# %%
age = 10
if age <= 12:
    print("Travel for free.")
else:
    print("Pay for ticket.")
# Out:
# Travel for free.

# %%
marks = 45
res = "Pass" if marks >= 40 else "Fail"
print(f"Result: {res}")
# Out:
# Result: Pass

# %%
marks = 45
res = "Pass" if marks >= 50 else "Fail"
print(f"Result: {res}")
# Out:
# Result: Fail

# %%
age = 25
if age <= 12:
    print("Child.")
elif age <= 19:
    print("Teenager.")
elif age <= 35:
    print("Young Adult.")
else:
    print("Adult.")
# Out:
# Young Adult.

# %%
age = 70
is_member = True
if age >= 60:
    if is_member:
        print("30% senior discount!")
    else:
        print("20% senior discount.")30
else: 
    print("Not eligible for a senior discount.")
# Out:
# 30% senior discount!

# %%
age = 70
is_member = True

if age >=60:
    if is_member:
        print("30% senior discount!")
    else:
        print("20% senior_ discount.")
else:
    print("Not eligible for a senior discount.")
# Out:
# 30% senior discount!
