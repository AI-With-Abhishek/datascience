# %%
import numpy as np
x = 4
r = x % 2

if r == 0:
    print("Even number")

# %%
x = 5
r = x % 2

if r == 0:
    print("Even number")

# %%
x = 5 
r = x % 2

if r == 0:
    print("even number")

print("odd number")

# %%
x = 8 
r = x % 2

if r == 0:
    print("Even number")
if r == 1:
    print("odd number")

# %%
x = 5
r = x % 2

if r == 0:
    print("Even number")
if r == 1:
    print("odd number")

# %%
x = 5
r = x % 2
if r == 0:
    print("Even number")
if r != 0:
    print("odd number")
if r == 1:
    print("odd number")

# %%
x = 11
r = x % 2
if r == 0:
    print("even number")
else:
    print("odd number")

# %%
x = 10
r = x % 2

if r == 0:
    print("even number")
else:
    print("odd number")

# %%
x = 3
r = x % 2

if r == 0:
    print("even number")
    if x > 5:
        print("greater number")

else:
    print("odd number")

# %%
x = 4 
r = x % 2
if r == 0:
    print("even number")
    if x>5:
        print("greater number")

else:
    print("odd number")

# %%
x = 4
r = x % 2
if r == 0:
    print("even number")
    if x>5:
        print("greater number")
    else:
        print("smaller number")
else:
    print("odd number")

# %%
x = 1 
if x == 1:
    print("one")
if x == 2:
    print("two")
if x == 3:
    print("three")
if x == 4:
    print("four")

# %%
x = 4

if x == 1:
    print("one")
elif x == 2:
    print("two")
elif x == 3:
    print("three")
elif x == 4:
    print("four")

# %%
x = 5
if x == 1:
    print("one")
elif x == 2:
    print("two")
elif x == 3:
    print("three")
elif x == 4:
    print("four")
else:
    print("number not found")

# %% [markdown]
# #LOOPS

# %% [markdown]
# #LOOPS

# %%
print("data science")
print("data science")
print("data science")
print("data science")
print("data science")

# %%
i = 1
while i<=5:
    print("data science")
    i = i + 1

# %%
i = 5

while i>1:
    print("data science")
    i = i - 1

# %%
i = 5        

while i>=1:    
    print('data science')
    i = i - 1

# %%
i = 1
while i<=5:
    print("data science :",i)
    i = i + 1

# %%
i = 5
while i>=1:
    print("data science : ", i)
    i = i - 1

# %%
i = 1

while i<= 5:
    print("data science")
    j = 1
    while j <= 4:
        print("technology")
        j = j + 1
i = i + 1
print()

# %%
i = 1

while i<= 5:
    print("data science")
    j = 1
    while j <= 4:
        print("technology")
         j = j + 1
         i = i + 1
         print()

# %%
i = 1
while i<=5:
    print("datascience", end = "")
    j = 1
    while j<=4:
        print("technplogy", end = "")
        j = j + 1
