# %%
language = 'python'
first_letter = language[3]
print(first_letter)
last_indesx = len(language) -1
last_letter = language[last_index]
print(last_letter)
# Out:
# h
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       3 print(first_letter)
#       4 last_indesx = len(language) -1
# ----> 5 last_letter = language[last_index]
#       6 print(last_letter)
#
# NameError: name 'last_index' is not defined

# %%
language = "PYTHON"
last_indesx = len(language) -1
last_letter = language[last_index]
print(last_letter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 language = "PYTHON"
#       2 last_indesx = len(language) -1
# ----> 3 last_letter = language[last_index]
#       4 print(last_letter)
#
# NameError: name 'last_index' is not defined

# %%
language = "python"
last_letter = language[-1]
print(last_letter)
second_last = language[-2]
print(second_last)
# Out:
# n
# o

# %%
language = 'Python'
first_three = language[0:3] 
last_three = language[3:6]
print(last_three) 
last_three = language[-3:]
print(last_three) 
last_three = language[3:]
print(last_three)
# Out:
# hon
# hon
# hon

# %%
language = "python"
pto = language[0:6:2]
print(pto)
# Out:
# pto

# %%
print('I hope every one enjoying the python challenge.\nDo you ?') # line break
print('Days\tTopics\tExercises')
print('Day 1\t3\t5')
print('Day 2\t3\t5')
print('Day 3\t3\t5')
print('Day 4\t3\t5')
print('This is a back slash  symbol (\\)') # To write a back slash
print('In every programming language it starts with \"Hello, World!\"')
# Out:
# I hope every one enjoying the python challenge.
# Do you ?
# Days	Topics	Exercises
# Day 1	3	5
# Day 2	3	5
# Day 3	3	5
# Day 4	3	5
# This is a back slash  symbol (\)
# In every programming language it starts with "Hello, World!"

# %%
challenge = "thirty days of python"
print(challenge.capitalize())
# Out:
# Thirty days of python

# %%
challenge = 'thirty days of python'
print(challenge.count('y')) # 3
print(challenge.count('y', 7, 14)) # 1
print(challenge.count('th')) # 2
# Out:
# 3
# 1
# 2

# %%
challenge = 'thirty days of python'
print(challenge.endswith('on'))   # True
print(challenge.endswith('thon')) # False
# Out:
# True
# True

# %%
print("i hope every one enjoying the python challenge.\nDo You")
print("Days\tTopics\tExercises")
print("Day 1\t3\t5")
print("Day 2\t9\t3")
print("Day 3\t8\t7")
print("Day 4\t6\t0")
print("Day 5\t3\t5")
print("Thish is a back slash symbol (\\)")
print("In every programming language it starts with \"Hello World!\"")
# Out:
# i hope every one enjoying the python challenge.
# Do You
# Days	Topics	Exercises
# Day 1	3	5
# Day 2	9	3
# Day 3	8	7
# Day 4	6	0
# Day 5	3	5
# Thish is a back slash symbol (\)
# In every programming language it starts with "Hello World!"

# %%
challenge = "thirty\tdays\tof\tpython"
print(challenge.expandtabs(4))
print(challenge.expandtabs(10))
# Out:
# thirty  days    of  python
# thirty    days      of        python

# %%
challenge = "thirty days of python"
print(challenge.find("y"))
print(challenge.find("th"))
# Out:
# 5
# 0

# %%
first_name = "Asabeneh"
last_name = "Yetayeh"
job = "teacher"
country = "finland"
sentence = "I am {} {}. I am a {}. I Live in {}.".format(first_name, last_name, job, country)
print(sentence)
# Out:
# I am Asabeneh Yetayeh. I am a teacher. I Live in finland.

# %%
radius = 10
pi = 3.14
area = pi
result = "The Area of circle with {} is {}".format(str(radius),str(area))
print(result)
# Out:
# The Area of circle with 10 is 3.14

# %%
challenge = "ThirtyDaysPython"
print(challenge.isalnum())
# Out:
# True

# %%
challenge = "30DaysPython"
print(challenge.isalnum())
# Out:
# True

# %%
challenge = "thirty days of Python"
print(challenge.isalnum())
# Out:
# False

# %%
challenge = "thirty days of Python 2019"
print(challenge.isalnum())
# Out:
# False

# %%
challenge = "thirty days of Python"
print(challenge.isalnum())
num = '123'
print(num.isalpha())
# Out:
# False
# False

# %%
num = '123'
print(num.isalpha())
# Out:
# False

# %%
challenge = 'Thirty'
print(challenge.isdigit())
challenge = "30"
print(challenge.isdigit())
# Out:
# False
# True

# %%
num = '10'
print(num.isdecimal()) 
num = '10.5'
print(num.isdecimal())
# Out:
# True
# False

# %%
challenge = 'thirty days of python'
print(challenge.islower())
challenge = 'Thirty days of python'
print(Challenge.islower())
# Out:
# True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 4
#       2 print(challenge.islower())
#       3 challenge = 'Thirty days of python'
# ----> 4 print(Challenge.islower())
#
# NameError: name 'Challenge' is not defined

# %%
challenge = 'thirty days of python'
print(challenge.isupper()) 
challenge = 'THIRTY DAYS OF PYTHON'
print(challenge.isupper())
# Out:
# False
# True

# %%
num = '10'
print(num.isnumeric())
print('ten'.isnumeric())
# Out:
# True
# False

# %%
web_tech = ['HTML','CSS','JvaScript','React']
result = '#,  '.join(web_tech)
print(result)
# Out:
# HTML#,  CSS#,  JvaScript#,  React

# %%
challenge = 'thirty days of python'
print(challenge.strip('y'))
# Out:
# thirty days of python

# %%
challenge = 'thirty days of python'
print(challenge.replace('python','coding'))
# Out:
# thirty days of coding

# %%
challenge = ' thirty days of python '
print(challenge.split())
# Out:
# ['thirty', 'days', 'of', 'python']

# %%
challenge = ' thirty days of python '
print(challenge.title())
# Out:
#  Thirty Days Of Python

# %%
challenge = ' thirty days of python '
print(challenge.swapcase())
challenge = ' thirty days of python '
print(challenge.swapcase())
# Out:
#  THIRTY DAYS OF PYTHON
#  THIRTY DAYS OF PYTHON

# %%
challenge = 'thirty days of python'
print(challenge.startswith('thirty')) 
challenge = '30 days of python'
print(challenge.startswith('thirty'))
# Out:
# True
# False
