# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,"python")
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=10
num2=20
add=num1+num2
print(add)
# Out:
# 30

# %% [markdown]
# # **print result with string**

# %%
num1=20
num2=30
add=num1+num2
print("the addition of",num1,"and",num2,"is=",add)
# Out:
# the addition of 20 and 30 is= 50

# %%
name="abhishek"
age=28
city="varanasi"
print("my nane is",name,"and i am",age,"year old form",city)
# Out:
# my nane is abhishek and i am 28 year old form varanasi

# %%
num1=100
num2=200
add=num1+num2
print("the addition of {} and {} is={}".format(num1,num2,add))
# Out:
# the addition of 100 and 200 is=300

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3
avg1=round((num1+num2+num3)/3,2)
print("the avrage of {}, {},and {} is= {} or {}".format(num1,num2,num3,avg,avg1))
# Out:
# the avrage of 100, 25,and 333 is= 152.66666666666666 or 152.67

# %%
round(avg,2)
# Out:
# 152.67

# %%
num1=20
num2=30
add=num1+num2
print(f'the addition of {num1} and {num2} is={add}')
# Out:
# the addition of 20 and 30 is=50

# %%
num1=10
num2=20
add = num1+ num2
print('The addition of',num1,'and',num2,'is=',add)
print('The addition of {} and {} is= {}'.format(num1,num2,add))
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 10 and 20 is= 30
# The addition of 10 and 20 is= 30
# The addition of 10 and 20 is= 30

# %%
End statement

# %% [markdown]
# ## **End statement**

# %%
print('Hello')
print('good morning')
# Out:
# Hello
# good morning

# %%
print('Hello', end=' ')
print('world good day')
# Out:
# Hello world good day

# %% [markdown]
# ### **Seprator**

# %%
print('Hello','Hai','How are you',sep='---->')
# Out:
# Hello---->Hai---->How are you

# %%
print('hello','hai','how are you',sep='&')
# Out:
# hello&hai&how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello','hai','how are you',sep=' ')
# Out:
# hello hai how are you

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(3,'.',sep='')
# Out:
# 3.

# %%
print(1,2,end='   ')
print(3,'.',sep='')
# Out:
# 1 2   3.

# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
# help> "symbols"
#
# Here is a list of the punctuation symbols which Python assigns special meaning
# to. Enter any symbol to get more help.
#
# !=                  +                   <=                  __
# "                   +=                  <>                  `
# """                 ,                   ==                  b"
# %                   -                   >                   b'
# %=                  -=                  >=                  f"
# &                   .                   >>                  f'
# &=                  ...                 >>=                 j
# '                   /                   @                   r"
# '''                 //                  J                   r'
# (                   //=                 [                   u"
# )                   /=                  \                   u'
# *                   :                   ]                   |
# **                  <                   ^                   |=
# **=                 <<                  ^=                  ~
# *=                  <<=                 _
#
# help> quit
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
1var = 10
# Out:
#   File "/tmp/ipython-input-4256868957.py", line 1
#     1var = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
val2@= 35
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1336790921.py in <cell line: 0>()
# ----> 1 val2@= 35
#
# NameError: name 'val2' is not defined

# %%
import = 125
# Out:
#   File "/tmp/ipython-input-4166699667.py", line 1
#     import = 125
#            ^
# SyntaxError: invalid syntax

# %%
"""
correct way defining an identifier
(identifiers can be a combination of letters in lowercase (a to z) or uppercase)
"""
val2 = 10

# %%
val_ = 99

# %% [markdown]
# # comments in python

# %%
#  """  """""

# %% [markdown]
# # Statments

# %%
p = 20
q = 30
r = q
p , type(p) , hex (id(p))
# Out:
# (20, int, '0xb1d748')

# %%
q , type(q), hex(id(q))
# Out:
# (30, int, '0xb1d888')

# %%
r  , type(r), hex(id(r))
# Out:
# (30, int, '0xb1d888')

# %%
p = 20
p = p + 10
p
# Out:
# 30

# %% [markdown]
# ## Variable assignment

# %%
intvar = 10
floatvar = 2.57
strvar = "Abhishek"


print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Abhishek

# %% [markdown]
# ### multiple assignments

# %%
intvar , floatvar , strvar = 10 , 2.57 , "Abhishek"

print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Abhishek

# %%
p1 = p2 = p3 = p4 = 44
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# # data types

# %% [markdown]
# # numeric

# %%
val1 = 10
print(val1)
print(type(val1))
print(sys.getsizeof(val1))
print(val1, "is integer?", isinstance(val1,int))
# Out:
# 10
# <class 'int'>
# 28
# 10 is integer? True

# %%
val2 = 92.78
print(val2)
print(type(val2))
print(sys.getsizeof(val2))
print(val2, "is float?", isinstance(val2,float))
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78 is float? True

# %%
val3 = 25 + 10j
print(val3)
print(type(val3))
print(sys.getsizeof(val3))
print(val3, "is complex?", isinstance(val3,complex))
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j) is complex? True

# %%
sys.getsizeof(int())
# Out:
# 28

# %%
sys.getsizeof(float())
# Out:
# 24

# %%
sys.getsizeof(complex())
# Out:
# 32

# %% [markdown]
# # boolean

# %%
bool1 = True
bool2 = False
print(type(bool1))
print(type(bool2))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
isinstance(bool1,bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # string

# %% [markdown]
# # string cration

# %%
str1 = "hello world"
print(str1)
# Out:
# hello world

# %%
mystr = "hello"
print(mystr)
# Out:
# hello

# %%
mystr = """ hello
                 world"""
print(mystr)
# Out:
#  hello
#                  world

# %%
mystr = (" happy "
          " monday "
          " everyone ")
print(mystr)
# Out:
#  happy  monday  everyone

# %%
mystr2 = "woohoo "
mystr2 = mystr2*5
mystr2
# Out:
# 'woohoo woohoo woohoo woohoo woohoo '

# %%
len(mystr2)
# Out:
# 35

# %% [markdown]
# # string indexing

# %% [markdown]
# Forward Indexing
# # Backward Indexing

# %%
str1
# Out:
# 'hello world'

# %%
str1[0]
# Out:
# 'h'

# %%
str1[len(str1)-1]
# Out:
# 'd'

# %%
str1[-1]
# Out:
# 'd'

# %%
str1[6]
# Out:
# 'w'

# %%
str1[5]
# Out:
# ' '

# %% [markdown]
# # string slicing

# %%
str1[0:5]
# Out:
# 'hello'

# %%
str1[6:12]
# Out:
# 'world'

# %%
str1[-4:]
# Out:
# 'orld'

# %%
str1[-6:]
# Out:
# ' world'

# %%
str1[:4]
# Out:
# 'hell'

# %%
str1[:6]
# Out:
# 'hello '

# %% [markdown]
# # update & delete string

# %%
str1
# Out:
# 'hello world'

# %%
str1[0:5] = "HOLAA"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1380185230.py in <cell line: 0>()
# ----> 1 str1[0:5] = "HOLAA"
#
# TypeError: 'str' object does not support item assignment

# %%
del str1
print(str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3327397269.py in <cell line: 0>()
# ----> 1 del str1
#       2 print(str1)
#
# NameError: name 'str1' is not defined

# %% [markdown]
# # string concatenation

# %%
s1 = "hello "
s2 = "abhishek"
s3 = s1 + s2
print(s3)
# Out:
# hello abhishek
